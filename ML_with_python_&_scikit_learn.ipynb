# %% [markdown]
# <a href="https://colab.research.google.com/github/khadeja258/Data-Analytics/blob/main/ML_with_python_%26_scikit_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
medical_url = "https://raw.githubusercontent.com/JovianML/opendatasets/master/data/medical-charges.csv"
from urllib.request import urlretrieve
urlretrieve(medical_url, 'medical.csv')
# Out:
# ('medical.csv', <http.client.HTTPMessage at 0x79db0a8e9750>)

# %%
medical = pd.read_csv('medical.csv')
medical
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
medical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
medical.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size'] = 14
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['figure.facecolor'] = '#00000000'

# %%
medical.age.describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
sns.histplot(medical['age'],bins = 47)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x='age',data=medical,width=0.3,color='green')
# Out:
# <Axes: xlabel='age'>

# %%
medical.bmi.describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
sns.histplot(medical['bmi'],color ='red')
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
sns.boxplot(x='bmi',data=medical,color='red')
# Out:
# <Axes: xlabel='bmi'>

# %%
sns.histplot(data = medical, x='charges',hue ='smoker',palette='dark')
plt.title("Annual Charges with Smokers")
# Out:
# Text(0.5, 1.0, 'Annual Charges')

# %%
sns.boxplot(data=medical,x='charges',hue='smoker',width=0.5,palette='dark')
plt.title('Annual Charges with Smokers')
# Out:
# Text(0.5, 1.0, 'Annual Charges')

# %%
sns.histplot(data = medical, x='charges',hue ='sex',palette='dark')
plt.title("Annual Charges with Sex")
# Out:
# Text(0.5, 1.0, 'Annual Charges with Sex')

# %%
sns.boxplot(data=medical,x='charges',hue='sex',width=0.5,palette='dark')
plt.title('Annual Charges with Sex')
# Out:
# Text(0.5, 1.0, 'Annual Charges with Sex')

# %%
sns.histplot(data = medical, x='charges',hue ='region',palette='dark')
plt.title("Annual Charges with region")
# Out:
# Text(0.5, 1.0, 'Annual Charges with region')

# %%
sns.boxplot(data=medical,x='charges',hue='region',width=0.5,palette='dark')
plt.title('Annual Charges with region')
# Out:
# Text(0.5, 1.0, 'Annual Charges with region')

# %%
 medical.smoker.value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
sns.histplot(x='smoker',data=medical,hue='sex',palette='dark')
plt.title('smoker')
# Out:
# Text(0.5, 1.0, 'smoker')

# %%
sns.histplot(data=medical,x='sex',hue='smoker',palette='dark')
plt.title('Smokers by Sex')
# Out:
# Text(0.5, 1.0, 'Smokers by Sex')

# %%
sns.histplot(x='region',data=medical,hue='smoker',palette='dark')
plt.title('Distribution by Region')
# Out:
# Text(0.5, 1.0, 'Distribution by Region')

# %%
sns.histplot(x='children',data=medical,hue='sex',palette='dark')
plt.title('No of children by Sex')
# Out:
# Text(0.5, 1.0, 'No of children by Sex')

# %%
sns.scatterplot(x='age',y='charges',data = medical,hue ='smoker',alpha =0.8,palette='YlGnBu')
plt.title('Age vs Charges')
# Out:
# Text(0.5, 1.0, 'Age vs Charges')

# %%
sns.scatterplot(x='bmi',y='charges',data = medical,hue ='smoker',alpha =0.8,palette='YlGnBu')
plt.title('BMI vs Charges')
# Out:
# Text(0.5, 1.0, 'BMI vs Charges')

# %%
sns.violinplot(x='children',y='charges',data=medical,palette='Set2')
plt.title('Children Vs Charges')
# Out:
# /tmp/ipython-input-65-1956898907.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='children',y='charges',data=medical,palette='Set2')
# Text(0.5, 1.0, 'Children Vs Charges')

# %%
sns.barplot(x='children',y='charges',data=medical)
plt.title('Children vs Charges')
# Out:
# Text(0.5, 1.0, 'Children vs Charges')

# %%
sns.violinplot(x='sex',y='charges',data=medical)
plt.title('Sex Vs Charges')
# Out:
# Text(0.5, 1.0, 'Sex Vs Charges')

# %%
sns.barplot(x='sex',y='charges',data=medical)
plt.title('Sex vs Charges')
# Out:
# Text(0.5, 1.0, 'Sex vs Charges')

# %%
sns.violinplot(x='region',y='charges',data=medical)
plt.title('Region Vs Charges')
# Out:
# Text(0.5, 1.0, 'Region Vs Charges')

# %%
sns.barplot(x='region',y='charges',data=medical)
plt.title('region vs Charges')
# Out:
# Text(0.5, 1.0, 'region vs Charges')

# %%
sns.violinplot(x='smoker',y='charges',data=medical)
plt.title('Smoker Vs Charges')
# Out:
# Text(0.5, 1.0, 'Smoker Vs Charges')

# %%
sns.barplot(x='smoker',y='charges',data=medical)
plt.title('Smoker vs Charges')
# Out:
# Text(0.5, 1.0, 'Smoker vs Charges')

# %%
medical.charges.corr(medical.age)
# Out:
# np.float64(0.2990081933306476)

# %%
medical.charges.corr(medical.bmi)
# Out:
# np.float64(0.19834096883362895)

# %%
medical.charges.corr(medical.children)
# Out:
# np.float64(0.06799822684790478)

# %%
Smoker_val = {'no': 0,'yes':1}
Smoker_numeric = medical.smoker.map(Smoker_val)
medical.charges.corr(Smoker_numeric)
# Out:
# np.float64(0.787251430498478)

# %%
Sex_val = {'male': 0,'female':1}
Sex_numeric = medical.sex.map(Sex_val)
medical.charges.corr(Sex_numeric)
# Out:
# np.float64(-0.057292062202025484)

# %%
corr_matrix = medical.select_dtypes(include='number').corr()
corr_matrix
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.heatmap(corr_matrix, cmap='Reds', annot=True)
plt.title('Correlation Matrix');

# %% [markdown]
# We know age and smoker have greatest corr with charges.

# %% [markdown]
# Linear Regression

# %%
non_smoker = medical[medical.smoker =='no']

# %%
sns.scatterplot(data=non_smoker,x='age',y='charges',alpha=0.7)
plt.title("Age vs Charges")
# Out:
# Text(0.5, 1.0, 'Age vs Charges')

# %% [markdown]
# The values in the "age" column of the dataset are called the inputs to the model and the values in the charges column are called "targets"

# %% [markdown]
# charges=w×age+b  w=weight and b=bias

# %%
def estimate_charges(age, w, b):
    return w * age + b

# %%
w = 50
b = 100

# %%
estimate_charges(40,w,b)
# Out:
# 2100

# %%
ages = non_smoker.age
ages
# Out:
# 1       18
# 2       28
# 3       33
# 4       32
# 5       31
#         ..
# 1332    52
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# Name: age, Length: 1064, dtype: int64

# %%
estimated_charges = estimate_charges(ages,w,b)
estimated_charges
# Out:
# 1       1000
# 2       1500
# 3       1750
# 4       1700
# 5       1650
#         ...
# 1332    2700
# 1333    2600
# 1334    1000
# 1335    1000
# 1336    1150
# Name: age, Length: 1064, dtype: int64

# %%
target = non_smoker.charges
target
# Out:
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
# 5        3756.62160
#            ...
# 1332    11411.68500
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# Name: charges, Length: 1064, dtype: float64

# %%
plt.plot(ages, estimated_charges,'r-o');
plt.xlabel('Age');
plt.ylabel('Estimated Charges');

# %%
def try_parameters(w, b):
    ages = non_smoker.age
    target = non_smoker.charges

    estimated_charges = estimate_charges(ages, w, b)

    plt.plot(ages, estimated_charges, alpha=0.9)
    plt.scatter(ages, target,alpha=0.8)
    plt.xlabel('Age');
    plt.ylabel('Charges')
    plt.legend(['Estimate', 'Actual'])

# %%
try_parameters(200,600)

# %%
try_parameters(400,4000)
